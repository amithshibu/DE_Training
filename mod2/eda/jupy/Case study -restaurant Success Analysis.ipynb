# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zomato_df=pd.read_csv("Data/zomato_restaurants.csv")
zomato_df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
zomato_df.head(3)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
#
#                                              address             name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...            Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...  San Churro Cafe
#
#   online_order book_table   rate  votes                           phone  \
# 0          Yes        Yes  4.1/5    775  080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                    080 41714161
# 2          Yes         No  3.8/5    918                  +91 9663487993
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
#
# ...

# %%
zomato_df.shape
# Out:
# (51717, 17)

# %%
zomato_df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
print(zomato_df.info() )#returns details like totale ntries(datas and rows),total data columns ,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
zomato_df[zomato_df.isnull()]
# Out:
#        url address name online_order book_table rate  votes phone location  \
# 0      NaN     NaN  NaN          NaN        NaN  NaN    NaN   NaN      NaN
# 1      NaN     NaN  NaN          NaN        NaN  NaN    NaN   NaN      NaN
# 2      NaN     NaN  NaN          NaN        NaN  NaN    NaN   NaN      NaN
# 3      NaN     NaN  NaN          NaN        NaN  NaN    NaN   NaN      NaN
# 4      NaN     NaN  NaN          NaN        NaN  NaN    NaN   NaN      NaN
# ...    ...     ...  ...          ...        ...  ...    ...   ...      ...
# 51712  NaN     NaN  NaN          NaN        NaN  NaN    NaN   NaN      NaN
# 51713  NaN     NaN  NaN          NaN        NaN  NaN    NaN   NaN      NaN
# 51714  NaN     NaN  NaN          NaN        NaN  NaN    NaN   NaN      NaN
# 51715  NaN     NaN  NaN          NaN        NaN  NaN    NaN   NaN      NaN
# 51716  NaN     NaN  NaN          NaN        NaN  NaN    NaN   NaN      NaN
#
# ...

# %%
zomato_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %% [markdown]
# #### 1.information about TOTAL  number of restaurants

# %%
zomato_df['name'].unique()
# Out:
# array(['Jalsa', 'Spice Elephant', 'San Churro Cafe', ..., 'Nawabs Empire',
#        'SeeYa Restaurant',
#        'Plunge - Sheraton Grand Bengaluru Whitefield Hotel &...'],
#       dtype=object)

# %%
len(zomato_df['name'].unique())
# Out:
# 8792

# %% [markdown]
# #### 2.PERCENTAGE WITH ONLINE ORDERS

# %%
yess = len(zomato_df[zomato_df['online_order'] == 'Yes']) / zomato_df['online_order'].count()
noo = len(zomato_df[zomato_df['online_order'] == 'No']) / zomato_df['online_order'].count()
percentage = pd.DataFrame({'Online Order': ['Yes', 'No'], 'Percentage': [yess, noo]})
print(percentage)

plt.pie([yes, no], labels=[f'Yes {yes*100:.2f}%', f'No {no*100:.2f}%'], autopct='%2.1f%%')
plt.title('Proportion of Online Orders')
plt.show()
# Out:
#   Online Order  Percentage
# 0          Yes    0.588665
# 1           No    0.411335

# %%
zomato_df['online_order'].value_counts()/zomato_df['online_order'].shape[0] * 100
# Out:
# online_order
# Yes    58.866524
# No     41.133476
# Name: count, dtype: float64

# %%
plt.pie(zomato_df['online_order'].value_counts(), 
        labels=zomato_df['online_order'].unique(), 
        autopct='%1.1f%%',colors=['red','green'])

plt.title('Online Order Distribution')

plt.show()

# %% [markdown]
# #### 3.rESTAURANT WITH ONLINE BOOK TABLE OPTION

# %%
yes = len(zomato_df[zomato_df['book_table'] == 'Yes']) / zomato_df['book_table'].count()
no = len(zomato_df[zomato_df['book_table'] == 'No']) / zomato_df['book_table'].count()

percentage = pd.DataFrame({'book_table': ['Yes', 'No'], 'Percentage': [yes**100, no*100]})
print(percentage)
plt.pie([yes, no], labels=[f'Yes {yes*100:.2f}%', f'No {no*100:.2f}%'], autopct='%2.1f%%',colors=['red','green'])

plt.title('Proportion of Online Orders')
plt.show()
# Out:
#   book_table    Percentage
# 0        Yes  3.853943e-91
# 1         No  8.753021e+01

# %% [markdown]
# #### Famous Chains in bengaluru

# %%
z=zomato_df['name'].value_counts().sort_values(ascending=False)[:21].index

z
# Out:
# Index(['Cafe Coffee Day', 'Onesta', 'Just Bake', 'Empire Restaurant',
#        'Five Star Chicken', 'Kanti Sweets', 'Petoo', 'Polar Bear',
#        'Baskin Robbins', 'Chef Baker's', 'Pizza Hut', 'Beijing Bites',
#        'Domino's Pizza', 'Sweet Truth', 'KFC', 'Subway', 'Smoor', 'McDonald's',
#        'Chai Point', 'Faasos', 'Lassi Shop'],
#       dtype='object', name='name')

# %%
z_count=zomato_df['name'].value_counts().sort_values(ascending=False)[:21].values

# %%
plt.figure(figsize=(8,9))
sns.set_style('whitegrid')
sns.barplot(y=z,x=z_count,orient='h',hue=z,palette='Reds',color='Red')
# Out:
# <Axes: ylabel='name'>

# %% [markdown]
# #### 5. Find mlst popularrestaurant type in bengaluru

# %%
rest_name=zomato_df['rest_type'].value_counts().sort_values(ascending=False)[:21].index
rest_name_count=zomato_df['rest_type'].value_counts().sort_values(ascending=False)[:21].values


rest_name_count
# Out:
# array([19132, 10330,  3732,  2604,  2263,  2037,  1154,  1141,   867,
#          697,   624,   468,   425,   396,   357,   346,   319,   298,
#          289,   267,   255])

# %%
zomato_df['rest_type'].value_counts().sort_values(ascending=False)[:21]
# Out:
# rest_type
# Quick Bites                   19132
# Casual Dining                 10330
# Cafe                           3732
# Delivery                       2604
# Dessert Parlor                 2263
# Takeaway, Delivery             2037
# Casual Dining, Bar             1154
# Bakery                         1141
# Beverage Shop                   867
# Bar                             697
# Food Court                      624
# Sweet Shop                      468
# Bar, Casual Dining              425
# Lounge                          396
# Pub                             357
# Fine Dining                     346
# Casual Dining, Cafe             319
# Beverage Shop, Quick Bites      298
# Bakery, Quick Bites             289
# Mess                            267
# Pub, Casual Dining              255
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,9))
sns.set_style('whitegrid')
sns.barplot(y=rest_name,x=rest_name_count,orient='h',hue=z,palette='Set1',color='Red')
# Out:
# <Axes: ylabel='rest_type'>

# %% [markdown]
# #### most popular restuarant type in Bengaluru is 'Quick Bites'.and least popular is POP up

# %% [markdown]
# #### 6. Distributiuin of restaurant cosat 2 person

# %%
zomato_df['approx_cost(for two people)'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '50', '190', '1,700', nan, '1,400', '180',
#        '1,350', '2,200', '2,000', '1,800', '1,900', '330', '2,500',
#        '2,100', '3,000', '2,800', '3,400', '40', '1,250', '3,500',
#        '4,000', '2,400', '2,600', '120', '1,450', '469', '70', '3,200',
#        '60', '560', '240', '360', '6,000', '1,050', '2,300', '4,100',
#        '5,000', '3,700', '1,650', '2,700', '4,500', '140'], dtype=object)

# %%
filt = zomato_df['approx_cost(for two people)'].apply(lambda x: str(x).replace(',', ''))

filt_float=filt.astype('float64')
#filt_num=pd.to_numeric(filt,downcast='integer')

filt_float
# Out:
# 0         800.0
# 1         800.0
# 2         800.0
# 3         300.0
# 4         600.0
#           ...
# 51712    1500.0
# 51713     600.0
# 51714    2000.0
# 51715    2500.0
# 51716    1500.0
# Name: approx_cost(for two people), Length: 51717, dtype: float64

# %%
zomato_df['approx_cost(for two people)']=zomato_df['approx_cost(for two people)'].str.replace(',','').astype('float64')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 zomato_df['approx_cost(for two people)']=zomato_df['approx_cost(for two people)'].str.replace(',','').astype('float64')
#
# File C:\Program Files\Python312\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File C:\Program Files\Python312\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
zomato_df['approx_cost(for two people)']
# Out:
# 0         800.0
# 1         800.0
# 2         800.0
# 3         300.0
# 4         600.0
#           ...
# 51712    1500.0
# 51713     600.0
# 51714    2000.0
# 51715    2500.0
# 51716    1500.0
# Name: approx_cost(for two people), Length: 51717, dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(14,8))
sns.set_style('whitegrid')
sns.distplot(zomato_df['approx_cost(for two people)'],color='blue')
# Out:
# <Axes: xlabel='approx_cost(for two people)', ylabel='Density'>

# %% [markdown]
# #### APPROX COST OF TWO PEPLE RANGE FROM RS 3000 TO 650,WITH MEDIAN COST APPROX 400,HENCE HAVE POSIITVE SKEWNESS

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(14,8))
sns.set_style('whitegrid')
sns.boxplot(zomato_df['approx_cost(for two people)'],color='blue',orient='h')
# Out:
# <Axes: xlabel='approx_cost(for two people)'>

# %%
zomato_df['approx_cost(for two people)'].median()
# Out:
# np.float64(400.0)

# %%
Q1=zomato_df['approx_cost(for two people)'].quantile(0.25)
Q2=zomato_df['approx_cost(for two people)'].quantile(0.5)
Q3=zomato_df['approx_cost(for two people)'].quantile(0.75)
print(Q1,Q2,Q3)
# Out:
# 300.0 400.0 650.0

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 350.0

# %% [markdown]
# ###

# %% [markdown]
# #### check if it is skewed?
#     INSIGHT:
#     YES THE APPROX COST FOR 2 PERSONS IS SKEWD TOWARDS POSITIVE SKEWENESS

# %% [markdown]
# #### find least popular restyarnt type in bengalur

# %%
#least popular
zomato_df['rest_type'].value_counts().sort_values(ascending=True)[:20]
# Out:
# rest_type
# Quick Bites, Kiosk            1
# Sweet Shop, Dessert Parlor    1
# Dessert Parlor, Kiosk         2
# Dessert Parlor, Food Court    2
# Pop Up                        2
# Food Court, Beverage Shop     2
# Bakery, Food Court            2
# Cafe, Food Court              2
# Bhojanalya                    3
# Bakery, Sweet Shop            3
# Mess, Quick Bites             3
# Club, Casual Dining           4
# Quick Bites, Meat Shop        4
# Casual Dining, Quick Bites    4
# Quick Bites, Mess             4
# Bar, Pub                      5
# Food Court, Casual Dining     5
# Fine Dining, Microbrewery     5
# Bar, Lounge                   6
# Food Court, Dessert Parlor    8
# Name: count, dtype: int64

# %%
least_rest_type=zomato_df['rest_type'].value_counts().sort_values(ascending=True)[:20].index
least_rest_type_count=zomato_df['rest_type'].value_counts().sort_values(ascending=True)[:20].values
plt.figure(figsize=(8,9))
sns.set_style('whitegrid')
sns.barplot(y=least_rest_type,x=least_rest_type_count,orient='h',hue=least_rest_type,palette='Set1',color='Red')
# Out:
# <Axes: ylabel='rest_type'>

# %%
least_rest_type=zomato_df['rest_type'].value_counts().sort_values(ascending=True)[:20].index
least_rest_type_count=zomato_df['rest_type'].value_counts().sort_values(ascending=True)[:20].values
plt.figure(figsize=(8,9))
sns.set_style('whitegrid')
sns.barplot(y=least_rest_type,x=least_rest_type_count,orient='h',hue=least_rest_type,palette='Set1',color='Red')

# %% [markdown]
# #### TOP 20 CMMON LOCATION WITH MOST NUMBER OF RESTAURANTS

# %%
c=zomato_df['listed_in(city)'].value_counts()
c
# Out:
# listed_in(city)
# BTM                      3279
# Koramangala 7th Block    2938
# Koramangala 5th Block    2836
# Koramangala 4th Block    2779
# Koramangala 6th Block    2623
# Jayanagar                2371
# JP Nagar                 2096
# Indiranagar              1860
# Church Street            1827
# MG Road                  1811
# Brigade Road             1769
# Lavelle Road             1744
# HSR                      1741
# Marathahalli             1659
# Residency Road           1620
# Whitefield               1620
# Bannerghatta Road        1617
# Brookefield              1518
# Old Airport Road         1425
# Kammanahalli             1329
# Kalyan Nagar             1309
# Basavanagudi             1266
# Sarjapur Road            1261
# Electronic City          1229
# Bellandur                1227
# Frazer Town              1185
# Malleshwaram             1096
# Rajajinagar              1079
# Banashankari              863
# New BEL Road              740
# ...

# %%
common_type=zomato_df['listed_in(city)'].value_counts().sort_values(ascending=False)[:20].index
common_type_count=zomato_df['listed_in(city)'].value_counts().sort_values(ascending=False)[:20].values

# %%
plt.figure(figsize=(8,9))
sns.set_style('whitegrid')
sns.barplot(y=common_type,x=common_type_count,orient='h',hue=common_type,palette='Set1',color='Red')
# Out:
# <Axes: ylabel='listed_in(city)'>

# %% [markdown]
# #### ANALYSIS :
# MOST POPULAR CITY IN BANGLORES ARE  BTM,BTM  ,Koramangala 7th Block,Koramangala 5th Block  ,Koramangala 4th Block

# %% [markdown]
# #### most popular quisines in banglore

# %%
zomato_df['cuisines'].value_counts()
# Out:
# cuisines
# North Indian                                2913
# North Indian, Chinese                       2385
# South Indian                                1828
# Biryani                                      918
# Bakery, Desserts                             911
#                                             ...
# French                                         1
# South Indian, Biryani, Chettinad, Juices       1
# North Indian, Street Food, Biryani             1
# Chinese, Mughlai                               1
# North Indian, Chinese, Arabian, Momos          1
# Name: count, Length: 2723, dtype: int64

# %%
quisines_popular=zomato_df['cuisines'].value_counts().sort_values(ascending=False)[:20].index
quisines_popular_count=zomato_df['cuisines'].value_counts().sort_values(ascending=False)[:20].values
quisines_popular
# Out:
# Index(['North Indian', 'North Indian, Chinese', 'South Indian', 'Biryani',
#        'Bakery, Desserts', 'Fast Food', 'Desserts', 'Cafe',
#        'South Indian, North Indian, Chinese', 'Bakery', 'Chinese',
#        'Ice Cream, Desserts', 'Chinese, North Indian', 'Mithai, Street Food',
#        'Desserts, Ice Cream', 'North Indian, Chinese, Biryani',
#        'North Indian, South Indian', 'South Indian, North Indian',
#        'North Indian, South Indian, Chinese', 'Beverages'],
#       dtype='object', name='cuisines')

# %%
quisines_popular_count
# Out:
# array([2913, 2385, 1828,  918,  911,  803,  766,  756,  726,  651,  556,
#         417,  415,  372,  354,  352,  343,  343,  305,  301])

# %%
plt.figure(figsize=(8,9))
sns.set_style('whitegrid')
sns.barplot(y=quisines_popular,x=quisines_popular_count,orient='h',hue=quisines_popular,palette='Set2',color='Red')
# Out:
# <Axes: ylabel='cuisines'>

# %% [markdown]
# #### INSIGHT
# bengalure odrers mostly 'North Indian', 'North Indian, Chinese', 'South Indian' foods

# %% [markdown]
# #### 10. DISTRIBUTUION OF RESTAURANT RATINGS

# %%
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
zomato_df['rate']=zomato_df['rate'].str.replace('/5','').replace('NEW',np.nan).replace('-',np.nan)
zomato_df['rate']=zomato_df['rate'].astype('float64')

# %%
zomato_df['rate']
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51712    3.6
# 51713    NaN
# 51714    NaN
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 51717, dtype: float64

# %%
zomato_df['rate']=='NEW'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Name: rate, Length: 51717, dtype: bool

# %%
plt.figure(figsize=(14,8))
sns.set_style('whitegrid')
sns.displot(zomato_df['rate'],color='red')
plt.show()

# %%
zomato_df['rate'].mode()
# Out:
# 0    3.9
# Name: rate, dtype: float64

# %% [markdown]
# #### FIND MOST TOP RATED RESTAURANT FROM EACH TOP 20 RESTAURANT CUSINES CATEGORY TYPES

# %%
top_rate=zomato_df['rest_type'].value_counts().sort_values(ascending=True)[:20].index
top_rate_count=zomato_df['rest_type'].value_counts().sort_values(ascending=False)[:20].values

# %%
top_rate#from this names find most rated restaurants
# Out:
# Index(['Quick Bites', 'Casual Dining', 'Cafe', 'Delivery', 'Dessert Parlor',
#        'Takeaway, Delivery', 'Casual Dining, Bar', 'Bakery', 'Beverage Shop',
#        'Bar', 'Food Court', 'Sweet Shop', 'Bar, Casual Dining', 'Lounge',
#        'Pub', 'Fine Dining', 'Casual Dining, Cafe',
#        'Beverage Shop, Quick Bites', 'Bakery, Quick Bites', 'Mess'],
#       dtype='object', name='rest_type')

# %%
grouped_restaurants = zomato_df.groupby('rest_type')[['name','rate']].max()
p1=pd.DataFrame(grouped_restaurants)
p2=pd.DataFrame(top_rate)
# Out:
#                                                                          name  \
# rest_type
# Bakery                                                               YummTumm
# Bakery, Beverage Shop                                                 Tea Bar
# Bakery, Cafe                Whitefield Baking Company - Bengaluru Marriott...
# Bakery, Dessert Parlor                                              Warm Oven
# Bakery, Food Court                                                 Oven Fresh
# ...                                                                       ...
# Sweet Shop                                                              Yumms
# Sweet Shop, Dessert Parlor                           Shree Mahalakshmi Sweets
# Sweet Shop, Quick Bites                     Vishal Sweets, Snacks & Breakfast
# Takeaway                                                       TheRiceBowl.In
# Takeaway, Delivery                                                  sCoolMeal
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[183], line 1
# ----> 1 pd.merge(grouped_restaurants,top_rate,how='inner')
#
# File C:\Program Files\Python312\Lib\site-packages\pandas\core\reshape\merge.py:153, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     135 @Substitution("\nleft : DataFrame or named Series")
#     136 @Appender(_merge_doc, indents=0)
#     137 def merge(
#    (...)
#     150     validate: str | None = None,
#     151 ) -> DataFrame:
#     152     left_df = _validate_operand(left)
# --> 153     right_df = _validate_operand(right)
#     154     if how == "cross":
#     155         return _cross_merge(
#     156             left_df,
#     157             right_df,
#    (...)
#     167             copy=copy,
#     168         )
#
# ...

# %%
grouped_restaurants = zomato_df.groupby('rest_type')[['name','rate']].max().filter(items=top_rated_restaurants,axis=0)
grouped_restaurants
# Out:
# Empty DataFrame
# Columns: [name, rate]
# Index: []

# %%
wef

# %% [markdown]
# #### 12.relationshio between rating and approx cost (for two people)

# %%
se filter to get common data frames')
# Out:
#   Cell In[190], line 1
#     sns.scatterplot(x='rate',y='approx_cost(for two people)',data=zomato_df,hue='rate',palette='Set1',hue='listed_in(type)')
#                                                                                                       ^
# SyntaxError: keyword argument repeated: hue
