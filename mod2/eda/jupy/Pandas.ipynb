# %%
import pandas as pd

# %% [markdown]
# raw_data=pd.read_csv("Data/Automobile_price_data__Raw_.csv")
# print(raw_data)

# %%
###1.Pandas Basics

# %%
type(raw_data)
# Out:
# pandas.core.frame.DataFrame

# %%
raw_data=pd.read_csv("Data/Automobile_price_data__Raw_.csv")
raw_data.head()#shows fitst 5 rows
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
raw_data.shape #rerturns tuple of size of rows and columns
# Out:
# (205, 26)

# %%
raw_data.tail()#show last columns
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
raw_data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
print(raw_data.info() )#returns details like totale ntries(datas and rows),total data columns ,
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
raw_data.isnull()#return true or flase ,for presnt and missing data cells,Falase:no missing
#True:there is missing value
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
raw_data.notnull()#oppsote of isnull
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 0         True               True  True       True        True          True
# 1         True               True  True       True        True          True
# 2         True               True  True       True        True          True
# 3         True               True  True       True        True          True
# 4         True               True  True       True        True          True
# ..         ...                ...   ...        ...         ...           ...
# 200       True               True  True       True        True          True
# 201       True               True  True       True        True          True
# 202       True               True  True       True        True          True
# 203       True               True  True       True        True          True
# 204       True               True  True       True        True          True
#
# ...

# %%
raw_data.head(2)#paarameters given for restricting numbers
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
#
# [2 rows x 26 columns]

# %% [markdown]
# ####2.DATA SLICING
# *USING loc() and iloc()

# %%
#loc takes index psotions and give the data
raw_data.loc[1:10]  #label based indexing
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 1           two  convertible          rwd           front        88.6  ...
# 2           two    hatchback          rwd           front        94.5  ...
# ...

# %%
raw_data.loc[:,'make':'wheel-base']#: says it exists in table
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
#     engine-location  wheel-base
# ...

# %%
raw_data.loc[:,:]#all roows and all columns
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
raw_data.loc[[1,3,5,6,7,8],['make','fuel-type','num-of-doors','wheel-base','width']]
# Out:
#           make fuel-type num-of-doors  wheel-base  width
# 1  alfa-romero       gas          two        88.6   64.1
# 3         audi       gas         four        99.8   66.2
# 5         audi       gas          two        99.8   66.3
# 6         audi       gas         four       105.8   71.4
# 7         audi       gas         four       105.8   71.4
# 8         audi       gas         four       105.8   71.4

# %%
raw_data.iloc[1:10]#last value is excluded just like oindexing
#start index is 1,end index=9
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 1  convertible          rwd           front        88.6  ...          130
# ...

# %%
raw_data.iloc[:,:]
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
#colums sliced by integer index

raw_data.iloc[:,2:12]#
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %%
#raw_data.iloc[row index,colum_index]
#raw_data.loc[raw_label,column_label]

# %% [markdown]
# ####3.ROWS AND COLUMS SELECTION

# %%
raw_data.columns[2:7]
# Out:
# Index(['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style'], dtype='object')

# %%
raw_data['make']#single column selectionr
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: make, Length: 205, dtype: object

# %%
raw_data[['make', 'fuel-type']]#selcting multiple columns by using lists
# Out:
#             make fuel-type
# 0    alfa-romero       gas
# 1    alfa-romero       gas
# 2    alfa-romero       gas
# 3           audi       gas
# 4           audi       gas
# ..           ...       ...
# 200        volvo       gas
# 201        volvo       gas
# 202        volvo       gas
# 203        volvo    diesel
# 204        volvo       gas
#
# [205 rows x 2 columns]

# %% [markdown]
# ###4.Filter

# %%
raw_data['make']=='audi' #tgis is just cndition returns true or false
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: make, Length: 205, dtype: bool

# %%
raw_data[raw_data['make']=='audi']
# Out:
#    symboling normalized-losses  make fuel-type aspiration num-of-doors  \
# 3          2               164  audi       gas        std         four
# 4          2               164  audi       gas        std         four
# 5          2                 ?  audi       gas        std          two
# 6          1               158  audi       gas        std         four
# 7          1                 ?  audi       gas        std         four
# 8          1               158  audi       gas      turbo         four
# 9          0                 ?  audi       gas      turbo          two
#
#   body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 3      sedan          fwd           front        99.8  ...          109
# 4      sedan          4wd           front        99.4  ...          136
# 5      sedan          fwd           front        99.8  ...          136
# 6      sedan          fwd           front       105.8  ...          136
# ...

# %%
#slciing dataframe using using multiple conditions
raw_data[(raw_data['make']=='toyota') & (raw_data['body-style']=='sedan')]
# Out:
#      symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 156          0                91  toyota       gas        std         four
# 158          0                91  toyota    diesel        std         four
# 160          0                91  toyota       gas        std         four
# 162          0                91  toyota       gas        std         four
# 163          1               168  toyota       gas        std          two
# 165          1               168  toyota       gas        std          two
# 173         -1                65  toyota       gas        std         four
# 174         -1                65  toyota    diesel      turbo         four
# 176         -1                65  toyota       gas        std         four
# 180         -1                90  toyota       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
#slciing dataframe using using multiple conditions
raw_data[(raw_data['make']=='toyota') | (raw_data['body-style']=='sedan')]
#it displays using eithe rog two conditions
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 3            2               164   audi       gas        std         four
# 4            2               164   audi       gas        std         four
# 5            2                 ?   audi       gas        std          two
# 6            1               158   audi       gas        std         four
# 8            1               158   audi       gas      turbo         four
# ..         ...               ...    ...       ...        ...          ...
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# #### 5.sorting

# %%
raw_data['wheel-base'].sort_values() # default ascending order
# Out:
# 31      86.6
# 30      86.6
# 18      88.4
# 0       88.6
# 1       88.6
#        ...
# 113    114.2
# 114    114.2
# 71     115.6
# 70     115.6
# 73     120.9
# Name: wheel-base, Length: 205, dtype: float64

# %%
raw_data['wheel-base'].sort_values(ascending=False)#descending
# Out:
# 73     120.9
# 71     115.6
# 70     115.6
# 114    114.2
# 113    114.2
#        ...
# 1       88.6
# 0       88.6
# 18      88.4
# 30      86.6
# 31      86.6
# Name: wheel-base, Length: 205, dtype: float64

# %%
raw_data.sort_values(by = 'engine-size')#sort entire dataframe by engine sie specificically
# Out:
#     symboling normalized-losses           make fuel-type aspiration  \
# 18          2               121      chevrolet       gas        std
# 57          3               150          mazda       gas        std
# 55          3               150          mazda       gas        std
# 56          3               150          mazda       gas        std
# 32          1               101          honda       gas        std
# ..        ...               ...            ...       ...        ...
# 48          0                 ?         jaguar       gas        std
# 47          0               145         jaguar       gas        std
# 74          1                 ?  mercedes-benz       gas        std
# 73          0                 ?  mercedes-benz       gas        std
# 49          0                 ?         jaguar       gas        std
#
#    num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 18          two  hatchback          fwd           front        88.4  ...
# ...

# %%
raw_data.sort_values(by = ['make','engine-size']).head(20)#first will sort by make and then engine-size
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
#sort maker by descending order,engine -size by asecding order
raw_data.sort_values(by = ['make','engine-size'],ascending=[False,True]).head(20)#first will sort by make and then engine-size
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 198         -2               103       volvo       gas      turbo
# 199         -1                74       volvo       gas      turbo
# 194         -2               103       volvo       gas        std
# 195         -1                74       volvo       gas        std
# 196         -2               103       volvo       gas        std
# 197         -1                74       volvo       gas        std
# 200         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 204         -1                95       volvo       gas      turbo
# 203         -1                95       volvo    diesel      turbo
# 202         -1                95       volvo       gas        std
# 182          2               122  volkswagen    diesel        std
# 184          2                94  volkswagen    diesel        std
# ...

# %%
#show all unique values of makers
raw_data['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
raw_data['make'].value_counts()#vale counts shows freqyuency of each category
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %% [markdown]
# ####6.FILTER AND QUERY

# %%
raw_data.filter(like='num')#filter subsets rows and columns of Dataframe
# Out:
#     num-of-doors num-of-cylinders
# 0            two             four
# 1            two             four
# 2            two              six
# 3           four             four
# 4           four             five
# ..           ...              ...
# 200         four             four
# 201         four             four
# 202         four              six
# 203         four              six
# 204         four             four
#
# [205 rows x 2 columns]

# %%
raw_data.filter(items=['make','num-of-doors','fuel-type','engine-size'])#slicing columns by using column names
# Out:
#             make num-of-doors fuel-type  engine-size
# 0    alfa-romero          two       gas          130
# 1    alfa-romero          two       gas          130
# 2    alfa-romero          two       gas          152
# 3           audi         four       gas          109
# 4           audi         four       gas          136
# ..           ...          ...       ...          ...
# 200        volvo         four       gas          141
# 201        volvo         four       gas          141
# 202        volvo         four       gas          173
# 203        volvo         four    diesel          145
# 204        volvo         four       gas          141
#
# [205 rows x 4 columns]

# %%
raw_data.filter(items=[0,1,4],axis=0)#slicing raws by raw label and axis =0
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 4         mpfi  3.19    3.40               8.0        115      5500       18
#
#   highway-mpg  price
# ...

# %%
raw_data.filter(regex='^e')
# Out:
#     engine-location engine-type  engine-size
# 0             front        dohc          130
# 1             front        dohc          130
# 2             front        ohcv          152
# 3             front         ohc          109
# 4             front         ohc          136
# ..              ...         ...          ...
# 200           front         ohc          141
# 201           front         ohc          141
# 202           front        ohcv          173
# 203           front         ohc          145
# 204           front         ohc          141
#
# [205 rows x 3 columns]

# %%
raw_data.query("make=='toyota' and `engine-size`>=130")
# Out:
#      symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 167          2               134  toyota       gas        std          two
# 168          2               134  toyota       gas        std          two
# 169          2               134  toyota       gas        std          two
# 170          2               134  toyota       gas        std          two
# 171          2               134  toyota       gas        std          two
# 172          2               134  toyota       gas        std          two
# 178          3               197  toyota       gas        std          two
# 179          3               197  toyota       gas        std          two
# 180         -1                90  toyota       gas        std         four
# 181         -1                 ?  toyota       gas        std         four
#
#       body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# ###7.hANDLING mISSING VALUES-DATA MANIPUTLAION AND DATA WRANKLING

# %%
import numpy as np

# %%
#replace ? by nan and update dataframe same
raw_data.replace('?',np.nan,inplace=True)

# %%
raw_data.isnull().sum()#returns total missing values from each column name
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#percentage of missing values %
raw_data.isnull().sum()/raw_data.shape[0] * 100
# Out:
# symboling             0.00000
# normalized-losses    20.00000
# make                  0.00000
# fuel-type             0.00000
# aspiration            0.00000
# num-of-doors          0.97561
# body-style            0.00000
# drive-wheels          0.00000
# engine-location       0.00000
# wheel-base            0.00000
# length                0.00000
# width                 0.00000
# height                0.00000
# curb-weight           0.00000
# engine-type           0.00000
# num-of-cylinders      0.00000
# engine-size           0.00000
# fuel-system           0.00000
# bore                  1.95122
# stroke                1.95122
# compression-ratio     0.00000
# horsepower            0.97561
# peak-rpm              0.97561
# city-mpg              0.00000
# highway-mpg           0.00000
# price                 1.95122
# dtype: float64

# %%
#normalized-losses having most missing datas so eliminate it
raw_data.drop(['symboling','normalized-losses'],axis=1,inplace=True) # axis=1 means deleteing columns
#inplace used in drop and replace only and some others

# %%
raw_data
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 200        volvo       gas        std         four        sedan          rwd
# 201        volvo       gas      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 204        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %%
raw_data['price']=raw_data['price'].astype('float64')

# %%
vehicle_df=raw_data.copy()

# %%
vehicle_df['price'].median()
# Out:
# 10295.0

# %%
#fill missing va;ues by median of rpice
raw_data['price']=raw_data['price'].fillna(vehicle_df['price'].median())#fillna is used to fill na values

# %%
vehicle_df.isnull().sum()
# Out:
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
vehicle_df.dropna(inplace=True)#drop missing rows from all columns

# %%
vehicle_df.isnull().sum()
# Out:
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
vehicle_df.isnull()
# Out:
#       make  fuel-type  aspiration  num-of-doors  body-style  drive-wheels  \
# 0    False      False       False         False       False         False
# 1    False      False       False         False       False         False
# 2    False      False       False         False       False         False
# 3    False      False       False         False       False         False
# 4    False      False       False         False       False         False
# ..     ...        ...         ...           ...         ...           ...
# 200  False      False       False         False       False         False
# 201  False      False       False         False       False         False
# 202  False      False       False         False       False         False
# 203  False      False       False         False       False         False
# 204  False      False       False         False       False         False
#
#      engine-location  wheel-base  length  width  ...  engine-size  \
# ...

# %% [markdown]
# ***mean if data is contiinous***
# ***median if data is deicrete ***
# ***mode if data is categorical***

# %% [markdown]
# ###Drop ducplaicate rows
# drop duplicates values

# %%
vehicle_df[vehicle_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [make, fuel-type, aspiration, num-of-doors, body-style, drive-wheels, engine-location, wheel-base, length, width, height, curb-weight, engine-type, num-of-cylinders, engine-size, fuel-system, bore, stroke, compression-ratio, horsepower, peak-rpm, city-mpg, highway-mpg, price]
# Index: []
#
# [0 rows x 24 columns]

# %%
dict(vehicle_df.loc[10])
# Out:
# {'make': 'bmw',
#  'fuel-type': 'gas',
#  'aspiration': 'std',
#  'num-of-doors': 'two',
#  'body-style': 'sedan',
#  'drive-wheels': 'rwd',
#  'engine-location': 'front',
#  'wheel-base': 101.2,
#  'length': 176.8,
#  'width': 64.8,
#  'height': 54.3,
#  'curb-weight': 2395,
#  'engine-type': 'ohc',
#  'num-of-cylinders': 'four',
#  'engine-size': 108,
#  'fuel-system': 'mpfi',
#  'bore': '3.50',
#  'stroke': '2.80',
#  'compression-ratio': 8.8,
#  'horsepower': '101',
#  'peak-rpm': '5800',
#  'city-mpg': 23,
#  'highway-mpg': 29,
#  'price': 16430.0}

# %%
sample_df=vehicle_df.sample(frac=0.05)#used tos elect random sample from dataframe using frac=0.05(5%) or n= same

# %%
vehicle_df1=pd.concat([vehicle_df,sample_df],ignore_index=True)

# %%
vehicle_df1[vehicle_df1.duplicated()]
# Out:
#            make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 193  mitsubishi       gas      turbo          two  hatchback          fwd
# 194      toyota       gas        std         four      wagon          fwd
# 195      subaru       gas      turbo         four      wagon          4wd
# 196       volvo       gas        std         four      sedan          rwd
# 197      toyota       gas        std          two  hatchback          rwd
# 198      nissan       gas        std         four      sedan          fwd
# 199      toyota       gas        std         four      sedan          fwd
# 200    plymouth       gas        std         four      wagon          fwd
# 201       volvo       gas        std         four      wagon          rwd
# 202      nissan       gas        std          two  hatchback          rwd
#
#     engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# ...

# %%
vehicle_df1.drop_duplicates(inplace=True)#drop all duplicates rows fron Dataframe

# %%
vehicle_df1
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0    alfa-romero       gas        std          two  convertible          rwd
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 3           audi       gas        std         four        sedan          fwd
# 4           audi       gas        std         four        sedan          4wd
# ..           ...       ...        ...          ...          ...          ...
# 188        volvo       gas        std         four        sedan          rwd
# 189        volvo       gas      turbo         four        sedan          rwd
# 190        volvo       gas        std         four        sedan          rwd
# 191        volvo    diesel      turbo         four        sedan          rwd
# 192        volvo       gas      turbo         four        sedan          rwd
#
# ...

# %%
####9.Group by 
*used for aggregate operations
# Out:
#   Cell In[233], line 2
#     *used for aggregate operations
#           ^
# SyntaxError: invalid syntax

# %%
vehicle_df1.groupby('make')['price'].mean()

# %%
vehicle_df1.groupby('make')[['city-mpg','price']].mean()

# %%
vehicle_df1.groupby('make')[['city-mpg','price']].max()

# %%
vehicle_df1.groupby('make')[['city-mpg','price']].max().sort_values(by = 'price',ascending=False)

# %% [markdown]
# ###10.apply()
# #used to apply() fucnton to modify the column values

# %%
vehicle_df1['Dimenision']=vehicle_df1.apply(lambda row:row['length']* row['width'],axis=1)

# %%
vehicle_df1.head()

# %% [markdown]
# vehicle_df1.set_index('')

# %% [markdown]
# 11.#set and Reset index

# %%
# import pandas as pd

# # Sample data: a dictionary with country names as keys and GDP values
# data = {
#     'Country': ['United States', 'China', 'Japan', 'Germany', 'India'],
#     'GDP (in trillion USD)': [25.3, 17.7, 4.9, 4.3, 3.7]
# }

# # Create DataFrame from the dictionary
# df = pd.DataFrame(data)

# # Display the DataFrame
# print(df)
# city_gdp=data

import pandas as pd

# Sample DataFrame
data = {'City': ['Bengaluru', 'Mumbai', 'Delhi'],
        'GDP': [110, 150, 130]}
city_gdp = pd.DataFrame(data)

# Resetting the index
city_gdp = city_gdp.reset_index()

print(city_gdp)

# %%
city_gdp=city_gdp.set_index('index')
city_gdp

# %% [markdown]
# ####12.PIVOT TABLE

# %%
vehicle_df1.pivot_table(values='price',index='drive-wheels',columns='fuel-type',aggfunc='mean')

# %%
vehicle_df1.pivot_table(values='price',index='drive-wheels',columns='body-style',aggfunc='mean')

# %%
#pivot table,created when we have categorical columns,used to convert columns to rows and viceversa
#

# %%
vehicle_df1.pivot_table(values='price',index=['drive-wheels','engine-location'],columns='body-style',aggfunc='mean')

# %% [markdown]
# ### 13.MERGE  common column requred

# %%
df1=pd.Series({
    'us':85858,
    'germany':53253,
    'japan':2244,
    'brazil':24421
},name='gdp_per_capita')


df2=pd.Series({
    'us':235523,
    'germany':32532,
    'japan':2325244,
    'brazil':24325421
},name='Population')

# %%
df11=pd.DataFrame(df1).reset_index()
df11.columns=['Country','Gdp_per_cpita']

# %%
df22=pd.DataFrame(df2).reset_index()
df22.columns=['Country','population']

# %%
df11

# %%
df22

# %%
pd.merge(df11,df22,on='Country',how='left')

# %% [markdown]
# pd.merge(df11,df22,on='Country',how='left')#similary inner,out,left,right

# %% [markdown]
# ###14.CROSSTAB
# #cross tabulation is panda method to crearte contigency tablethat shows frequncy distribution of
# attributes

# %%
pd.crosstab(vehicle_df1['body-style'],vehicle_df1['num-of-doors'])#frequncy table of two columns
